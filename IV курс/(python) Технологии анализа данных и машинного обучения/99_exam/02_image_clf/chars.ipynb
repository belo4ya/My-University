# %%
import copy
import typing as t
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn import metrics
from torch.utils.data import DataLoader, Dataset, Subset, random_split
from torchvision import transforms
from torchvision.datasets import ImageFolder

# %%
# @formatter:off
# %matplotlib inline
# @formatter:on

# %%
torch.set_warn_always(True)

sns.set_theme()
plt.rcParams["figure.figsize"] = (8, 4)

# %%
DATA_DIR = Path("../data/")

CUDA = "cuda"
CPU = "cpu"
DEVICE = CUDA if torch.cuda.is_available() else CPU
print(f"Using {DEVICE.upper()} device")
# Out:
# Using CUDA device

# %% [markdown]
# ## Предобработка данных и подготовка датасета

# %%
def show_sample_images(dataset: ImageFolder, cols: int = 3, rows: int = 3) -> None:
    _, axes = plt.subplots(cols, rows, figsize=(6, 6))
    for i, ax in zip(torch.randperm(len(dataset)), axes.flatten()):
        img, target = dataset[i]
        ax.axis("off")
        ax.set_title(dataset.classes[target])
        if img.mode == "RGB":
            ax.imshow(img)
        else:
            ax.imshow(img, cmap="gray")


def torch_train_test_split(dataset: t.Union[Dataset, t.Sized], test_size: float) -> t.Tuple[Subset, Subset]:
    test_size = round(test_size * len(dataset))
    train_size = len(dataset) - test_size
    train_dataset, test_dataset = random_split(dataset, lengths=(train_size, test_size))
    return train_dataset, test_dataset

# %%
base_transform = transforms.Compose([transforms.Resize(size=(128, 128))])
chars_dataset = ImageFolder(DATA_DIR / "images/chars", transform=base_transform)

vc = pd.value_counts(chars_dataset.targets)
vc.index = [chars_dataset.classes[i] for i in vc.index]
print(vc)
vc.plot.bar(rot=0, figsize=(3, 2.5));
# Out:
# marvel       193
# star-wars    139
# dtype: int64

# %%
torch.manual_seed(0)
show_sample_images(chars_dataset)

# %%
torch.manual_seed(0)

train_transform = transforms.Compose([
    *base_transform.transforms,
    transforms.RandomHorizontalFlip(p=0.25),
    transforms.RandomVerticalFlip(p=0.25),
    transforms.RandomRotation(degrees=(-30, 30)),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5)),
])
test_transform = transforms.Compose([
    *base_transform.transforms,
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5)),
])

train_dataset, test_dataset = torch_train_test_split(chars_dataset, test_size=0.25)
train_dataset.dataset = copy.deepcopy(train_dataset.dataset)
train_dataset.dataset.transform = train_transform
test_dataset.dataset = copy.deepcopy(test_dataset.dataset)
test_dataset.dataset.transform = test_transform

len(train_dataset), len(test_dataset)
# Out:
# (249, 83)

# %% [markdown]
# ## Построение и обучение модели

# %%
def get_weights(targets: torch.Tensor) -> torch.Tensor:
    _, counts = targets.unique(return_counts=True)
    return counts.max() / counts


def common_train(
        model: nn.Module,
        loss_fn: nn.Module,
        optimizer: optim.Optimizer,
        epochs: int,
        train_dataloader: DataLoader,
        test_dataloader: DataLoader,
        verbose: int = None,
        device: str = CPU,
) -> t.Tuple[t.List[float], t.List[float], t.List[float], t.List[float]]:
    train_losses, train_accuracy_list = [], []
    test_losses, test_accuracy_list = [], []
    for epoch in range(epochs):
        print(f"Epoch {epoch + 1}\n" + "-" * 32)

        train_loss, train_accuracy = train_loop(train_dataloader, model, loss_fn, optimizer, verbose, device)
        print(f"Train Error: loss: {train_loss:.6f}, accuracy: {train_accuracy:.4f}")
        train_losses.append(train_loss)
        train_accuracy_list.append(train_accuracy)

        test_loss, test_accuracy = test_loop(test_dataloader, model, loss_fn, device)
        print(f" Test Error: loss: {test_loss:.6f}, accuracy: {test_accuracy:.4f}\n")
        test_losses.append(test_loss)
        test_accuracy_list.append(test_accuracy)

        torch.cuda.empty_cache()
    return train_losses, train_accuracy_list, test_losses, test_accuracy_list


def train_loop(
        dataloader: DataLoader,
        model: nn.Module,
        loss_fn: nn.Module,
        optimizer: optim.Optimizer,
        verbose: int = None,
        device: str = CPU,
) -> t.Tuple[float, float]:
    model.train()

    size = len(dataloader.dataset)  # noqa
    num_batches = len(dataloader)
    avg_loss, avg_accuracy = 0, 0

    for batch, (x, y) in enumerate(dataloader):
        x, y = x.to(device), y.to(device)

        pred = model(x)
        loss = loss_fn(pred, y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        y_true = torch.flatten(y).detach().cpu()
        y_pred = torch.flatten(pred.argmax(1)).detach().cpu()
        accuracy = metrics.accuracy_score(y_true, y_pred)

        avg_loss += loss
        avg_accuracy += accuracy
        if verbose and batch % verbose == 0:
            print(f"[{batch * len(x):>4d}/{size:>4d}]: loss: {loss:.6f}, accuracy: {accuracy:.4f}")

        del x, y, pred, loss
        torch.cuda.empty_cache()

    return (avg_loss / num_batches).item(), avg_accuracy / num_batches


@torch.no_grad()
def test_loop(
        dataloader: DataLoader,
        model: nn.Module,
        loss_fn: nn.Module,
        device: str = CPU,
) -> t.Tuple[float, float]:
    model.eval()
    y_true, y_pred = get_y_true_y_pred(model, dataloader, device)
    return loss_fn(y_pred, y_true).item(), metrics.accuracy_score(y_true.cpu(), y_pred.argmax(1).cpu())


@torch.no_grad()
def get_y_true_y_pred(
        model: nn.Module,
        dataloader: DataLoader,
        device: str = CPU,
) -> t.Tuple[torch.Tensor, torch.Tensor]:
    model.eval()

    y_test = []
    y_pred = []
    for x, y in dataloader:
        x, y = x.to(device), y.to(device)
        pred = model(x)
        y_test.append(y.unsqueeze(1))
        y_pred.append(pred)

        del x
        torch.cuda.empty_cache()

    return torch.flatten(torch.vstack(y_test)), torch.vstack(y_pred)


def plot_train_test(
        train_losses: t.List[float],
        train_accuracy: t.List[float],
        test_losses: t.List[float],
        test_accuracy: t.List[float],
) -> None:
    fig, axes = plt.subplots(2, 1, figsize=(6, 7))
    epochs = torch.arange(len(train_losses))

    axes[0].plot(epochs, train_losses)
    axes[0].plot(epochs, test_losses)
    axes[0].set_ylabel("loss")
    axes[0].legend(["train", "test"])

    axes[1].plot(epochs, train_accuracy)
    axes[1].plot(epochs, test_accuracy)
    axes[1].set_xlabel("epoch")
    axes[1].set_ylabel("accuracy")

# %%
class CharsClassifier(nn.Module):  # ответственный подход к LEGO
    LAST_CONV_OUT_CHANNELS = 64
    ADAPTIVE_AVG_POOL = 8

    def __init__(self, num_channels: int, num_classes: int):
        super().__init__()
        self.features = nn.Sequential(
            nn.Conv2d(in_channels=num_channels, out_channels=32, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(True),
            nn.MaxPool2d(2),
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(True),
            nn.MaxPool2d(2),
            nn.Conv2d(in_channels=64, out_channels=self.LAST_CONV_OUT_CHANNELS, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(self.LAST_CONV_OUT_CHANNELS),
            nn.ReLU(True),
            nn.MaxPool2d(2),
        )
        self.avgpool = nn.AdaptiveAvgPool2d((self.ADAPTIVE_AVG_POOL, self.ADAPTIVE_AVG_POOL))
        self.classifier = nn.Sequential(
            nn.Linear(self.LAST_CONV_OUT_CHANNELS * self.ADAPTIVE_AVG_POOL * self.ADAPTIVE_AVG_POOL, 512),
            nn.ReLU(True),
            nn.Dropout(0.5),
            nn.Linear(512, 512),
            nn.ReLU(True),
            nn.Dropout(0.5),
            nn.Linear(512, 512),
            nn.ReLU(True),
            nn.Dropout(0.5),
            nn.Linear(512, num_classes),
        )

    def forward(self, x):
        x = self.features(x)
        x = self.avgpool(x)
        x = torch.flatten(x, 1)
        return self.classifier(x)

# %%
torch.manual_seed(0)

net = CharsClassifier(
    num_channels=train_dataset[0][0].size(0),
    num_classes=len(chars_dataset.classes),
).to(DEVICE)
weights = get_weights(torch.tensor([target for _, target in train_dataset], device=DEVICE))
loss_fn = nn.CrossEntropyLoss(weight=weights)
optimizer = optim.Adam(net.parameters(), lr=0.00015)

train_dataloader = DataLoader(train_dataset, batch_size=16, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=len(test_dataset))

net
# Out:
# CharsClassifier(
#   (features): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU(inplace=True)
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU(inplace=True)
#     (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(8, 8))
#   (classifier): Sequential(
#     (0): Linear(in_features=4096, out_features=512, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=512, out_features=512, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=512, out_features=512, bias=True)
#     (7): ReLU(inplace=True)
#     (8): Dropout(p=0.5, inplace=False)
#     (9): Linear(in_features=512, out_features=2, bias=True)
#   )
# )

# %%
# %%time

train_losses, train_accuracy, test_losses, test_accuracy = common_train(
    epochs=40,
    model=net,
    loss_fn=loss_fn,
    optimizer=optimizer,
    train_dataloader=train_dataloader,
    test_dataloader=test_dataloader,
    device=DEVICE,
)
# Out:
# Epoch 1
# --------------------------------
# Train Error: loss: 0.706337, accuracy: 0.5286
#  Test Error: loss: 0.693016, accuracy: 0.5301
#
# Epoch 2
# --------------------------------
# Train Error: loss: 0.698968, accuracy: 0.5182
#  Test Error: loss: 0.689309, accuracy: 0.5783
#
# Epoch 3
# --------------------------------
# Train Error: loss: 0.698372, accuracy: 0.5495
#  Test Error: loss: 0.683735, accuracy: 0.6024
#
# Epoch 4
# --------------------------------
# Train Error: loss: 0.710491, accuracy: 0.4813
#  Test Error: loss: 0.680387, accuracy: 0.6265
#
# Epoch 5
# --------------------------------
# Train Error: loss: 0.697984, accuracy: 0.5590
#  Test Error: loss: 0.671917, accuracy: 0.5904
#
# Epoch 6
# --------------------------------
# Train Error: loss: 0.697451, accuracy: 0.5933
#  Test Error: loss: 0.665820, accuracy: 0.6265
#
# Epoch 7
# --------------------------------
# Train Error: loss: 0.661272, accuracy: 0.5807
#  Test Error: loss: 0.653820, accuracy: 0.6627
#
# Epoch 8
# --------------------------------
# Train Error: loss: 0.651054, accuracy: 0.6081
#  Test Error: loss: 0.647623, accuracy: 0.6506
#
# Epoch 9
# --------------------------------
# Train Error: loss: 0.639389, accuracy: 0.6263
#  Test Error: loss: 0.634553, accuracy: 0.6145
#
# Epoch 10
# --------------------------------
# Train Error: loss: 0.617357, accuracy: 0.6450
#  Test Error: loss: 0.616000, accuracy: 0.6506
#
# Epoch 11
# --------------------------------
# Train Error: loss: 0.607355, accuracy: 0.6471
#  Test Error: loss: 0.603463, accuracy: 0.6506
#
# Epoch 12
# --------------------------------
# Train Error: loss: 0.588710, accuracy: 0.6823
#  Test Error: loss: 0.580146, accuracy: 0.6506
#
# Epoch 13
# --------------------------------
# Train Error: loss: 0.549253, accuracy: 0.6979
#  Test Error: loss: 0.578270, accuracy: 0.7108
#
# Epoch 14
# --------------------------------
# Train Error: loss: 0.521233, accuracy: 0.7283
#  Test Error: loss: 0.549579, accuracy: 0.6627
#
# Epoch 15
# --------------------------------
# Train Error: loss: 0.521394, accuracy: 0.7431
#  Test Error: loss: 0.523222, accuracy: 0.7229
#
# Epoch 16
# --------------------------------
# Train Error: loss: 0.481076, accuracy: 0.7548
#  Test Error: loss: 0.509472, accuracy: 0.6988
#
# Epoch 17
# --------------------------------
# Train Error: loss: 0.487177, accuracy: 0.7752
#  Test Error: loss: 0.493983, accuracy: 0.7229
#
# Epoch 18
# --------------------------------
# Train Error: loss: 0.428097, accuracy: 0.8016
#  Test Error: loss: 0.631776, accuracy: 0.7229
#
# Epoch 19
# --------------------------------
# Train Error: loss: 0.464737, accuracy: 0.7448
#  Test Error: loss: 0.504434, accuracy: 0.7711
#
# Epoch 20
# --------------------------------
# Train Error: loss: 0.424381, accuracy: 0.8199
#  Test Error: loss: 0.506096, accuracy: 0.8072
#
# Epoch 21
# --------------------------------
# Train Error: loss: 0.421906, accuracy: 0.8181
#  Test Error: loss: 0.475994, accuracy: 0.7349
#
# Epoch 22
# --------------------------------
# Train Error: loss: 0.421037, accuracy: 0.8073
#  Test Error: loss: 0.469235, accuracy: 0.8193
#
# Epoch 23
# --------------------------------
# Train Error: loss: 0.394221, accuracy: 0.8260
#  Test Error: loss: 0.495584, accuracy: 0.7831
#
# Epoch 24
# --------------------------------
# Train Error: loss: 0.366528, accuracy: 0.8611
#  Test Error: loss: 0.493605, accuracy: 0.7108
#
# Epoch 25
# --------------------------------
# Train Error: loss: 0.361011, accuracy: 0.8338
#  Test Error: loss: 0.489247, accuracy: 0.8193
#
# Epoch 26
# --------------------------------
# Train Error: loss: 0.312752, accuracy: 0.8867
#  Test Error: loss: 0.539327, accuracy: 0.8313
#
# Epoch 27
# --------------------------------
# Train Error: loss: 0.358898, accuracy: 0.8602
#  Test Error: loss: 0.543807, accuracy: 0.7831
#
# Epoch 28
# --------------------------------
# Train Error: loss: 0.363343, accuracy: 0.8477
#  Test Error: loss: 0.434810, accuracy: 0.7831
#
# Epoch 29
# --------------------------------
# Train Error: loss: 0.289967, accuracy: 0.8737
#  Test Error: loss: 0.466992, accuracy: 0.7590
#
# Epoch 30
# --------------------------------
# Train Error: loss: 0.354223, accuracy: 0.8424
#  Test Error: loss: 0.494102, accuracy: 0.7349
#
# Epoch 31
# --------------------------------
# Train Error: loss: 0.268369, accuracy: 0.8854
#  Test Error: loss: 0.568290, accuracy: 0.8434
#
# Epoch 32
# --------------------------------
# Train Error: loss: 0.312438, accuracy: 0.8689
#  Test Error: loss: 0.594581, accuracy: 0.7590
#
# Epoch 33
# --------------------------------
# Train Error: loss: 0.407972, accuracy: 0.8542
#  Test Error: loss: 0.510230, accuracy: 0.7590
#
# Epoch 34
# --------------------------------
# Train Error: loss: 0.295496, accuracy: 0.8533
#  Test Error: loss: 0.447640, accuracy: 0.8072
#
# Epoch 35
# --------------------------------
# Train Error: loss: 0.301966, accuracy: 0.8720
#  Test Error: loss: 0.560934, accuracy: 0.8072
#
# Epoch 36
# --------------------------------
# Train Error: loss: 0.310666, accuracy: 0.8837
#  Test Error: loss: 0.504197, accuracy: 0.7952
#
# Epoch 37
# --------------------------------
# Train Error: loss: 0.321700, accuracy: 0.8320
#  Test Error: loss: 0.477447, accuracy: 0.7952
#
# Epoch 38
# --------------------------------
# Train Error: loss: 0.277743, accuracy: 0.8759
#  Test Error: loss: 0.551538, accuracy: 0.7590
#
# Epoch 39
# --------------------------------
# Train Error: loss: 0.324278, accuracy: 0.8563
#  Test Error: loss: 0.479053, accuracy: 0.8313
#
# Epoch 40
# --------------------------------
# Train Error: loss: 0.358181, accuracy: 0.8385
#  Test Error: loss: 0.490943, accuracy: 0.8072
#
# CPU times: total: 7min 36s
# Wall time: 2min 3s

# %% [markdown]
# ## Оценка и выводы

# %%
plot_train_test(train_losses, train_accuracy, test_losses, test_accuracy)

# %%
y_true, y_pred = get_y_true_y_pred(net, test_dataloader, DEVICE)
y_true, y_pred = y_true.cpu(), y_pred.argmax(1).cpu()

# %%
cm_display = metrics.ConfusionMatrixDisplay.from_predictions(
    y_true,
    y_pred,
    display_labels=chars_dataset.classes,
    colorbar=False,
    xticks_rotation=0,
    cmap=sns.color_palette('light:b', as_cmap=True)
)
cm_display.ax_.grid(False)
cm_display.figure_.set_size_inches(3.5, 3.5)

# %%
print(metrics.classification_report(y_true, y_pred, target_names=chars_dataset.classes, zero_division=True))
# Out:
#               precision    recall  f1-score   support
#
#       marvel       0.82      0.85      0.83        47
#    star-wars       0.79      0.75      0.77        36
#
#     accuracy                           0.81        83
#    macro avg       0.81      0.80      0.80        83
# weighted avg       0.81      0.81      0.81        83

# %%
net.eval()

_, axes = plt.subplots(3, 3, figsize=(6, 7))
for i, ax in zip(torch.randperm(len(test_dataset)), axes.flatten()):
    img, _ = chars_dataset[test_dataset.indices[i]]  # картинка до нормализации

    x, target = test_dataset[i]
    pred = net(x.unsqueeze(0).to(DEVICE))

    pred_proba = torch.max(torch.softmax(pred, 1))
    pred_label = pred.argmax(1).item()
    ax.set_title(
        f"pred: {chars_dataset.classes[pred_label]} ({pred_proba:.2f})"
        f"\ntrue: {chars_dataset.classes[target]}", loc="left"
    )
    ax.axis("off")
    if img.mode == "RGB":
        ax.imshow(img)
    else:
        ax.imshow(img, cmap="gray")
