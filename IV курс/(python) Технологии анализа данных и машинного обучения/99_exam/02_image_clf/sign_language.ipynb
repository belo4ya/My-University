# %%
import copy
import typing as t
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn import metrics
from torch.utils.data import DataLoader, Dataset, Subset, random_split
from torchvision import transforms
from torchvision.datasets import ImageFolder
from tqdm import tqdm

# %%
# @formatter:off
# %matplotlib inline
# @formatter:on

# %%
torch.set_warn_always(True)

sns.set_theme()
plt.rcParams["figure.figsize"] = (8, 4)

# %%
DATA_DIR = Path("../data/")

CUDA = "cuda"
CPU = "cpu"
DEVICE = CUDA if torch.cuda.is_available() else CPU
print(f"Using {DEVICE.upper()} device")
# Out:
# Using CUDA device

# %% [markdown]
# ## Предобработка данных и подготовка датасета

# %%
def preprocess_images(dataset: ImageFolder, save_dir: Path) -> None:
    save_dir.mkdir(exist_ok=True)
    for cls in dataset.classes:
        (save_dir / cls).mkdir(exist_ok=True)

    for i in tqdm(range(len(dataset))):
        img, target = dataset[i]
        img.save(save_dir / dataset.classes[target] / Path(dataset.imgs[i][0]).name)


def show_sample_images(dataset: ImageFolder, cols: int = 3, rows: int = 3) -> None:
    _, axes = plt.subplots(cols, rows, figsize=(6, 6))
    for i, ax in zip(torch.randperm(len(dataset)), axes.flatten()):
        img, target = dataset[i]
        ax.axis("off")
        ax.set_title(dataset.classes[target])
        if img.mode == "RGB":
            ax.imshow(img)
        else:
            ax.imshow(img, cmap="gray")


def torch_train_test_split(dataset: t.Union[Dataset, t.Sized], test_size: float) -> t.Tuple[Subset, Subset]:
    test_size = round(test_size * len(dataset))
    train_size = len(dataset) - test_size
    train_dataset, test_dataset = random_split(dataset, lengths=(train_size, test_size))
    return train_dataset, test_dataset

# %%
base_transform = transforms.Compose([
    transforms.Resize(size=(48, 48)),
])

sign_dataset = ImageFolder(DATA_DIR / "images/sign_language", transform=base_transform)
save_dataset_dir = DATA_DIR / "images/sign_language_48"
preprocess_images(sign_dataset, save_dataset_dir)
sign_dataset = ImageFolder(save_dataset_dir)
# Out:
# 100%|██████████| 2062/2062 [00:03<00:00, 676.73it/s]

# %%
vc = pd.value_counts(sign_dataset.targets)
vc.index = [sign_dataset.classes[i] for i in vc.index]
vc.plot.bar(rot=0, figsize=(5, 3));

# %%
torch.manual_seed(0)
show_sample_images(sign_dataset)

# %%
torch.manual_seed(0)

train_transform = transforms.Compose([
    *base_transform.transforms,
    transforms.RandomHorizontalFlip(p=0.25),
    transforms.RandomVerticalFlip(p=0.25),
    transforms.RandomRotation(degrees=(-30, 30)),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5)),
])
test_transform = transforms.Compose([
    *base_transform.transforms,
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5)),
])

train_dataset, test_dataset = torch_train_test_split(sign_dataset, test_size=0.2)
train_dataset.dataset = copy.deepcopy(train_dataset.dataset)
train_dataset.dataset.transform = train_transform
test_dataset.dataset = copy.deepcopy(test_dataset.dataset)
test_dataset.dataset.transform = test_transform

len(train_dataset), len(test_dataset)
# Out:
# (1650, 412)

# %% [markdown]
# ## Построение и обучение модели

# %%
def get_weights(targets: torch.Tensor) -> torch.Tensor:
    _, counts = targets.unique(return_counts=True)
    return counts.max() / counts


def common_train(
        model: nn.Module,
        loss_fn: nn.Module,
        optimizer: optim.Optimizer,
        epochs: int,
        train_dataloader: DataLoader,
        test_dataloader: DataLoader,
        verbose: int = None,
        device: str = CPU,
) -> t.Tuple[t.List[float], t.List[float], t.List[float], t.List[float]]:
    train_losses, train_accuracy_list = [], []
    test_losses, test_accuracy_list = [], []
    for epoch in range(epochs):
        print(f"Epoch {epoch + 1}\n" + "-" * 32)

        train_loss, train_accuracy = train_loop(train_dataloader, model, loss_fn, optimizer, verbose, device)
        print(f"Train Error: loss: {train_loss:.6f}, accuracy: {train_accuracy:.4f}")
        train_losses.append(train_loss)
        train_accuracy_list.append(train_accuracy)

        test_loss, test_accuracy = test_loop(test_dataloader, model, loss_fn, device)
        print(f" Test Error: loss: {test_loss:.6f}, accuracy: {test_accuracy:.4f}\n")
        test_losses.append(test_loss)
        test_accuracy_list.append(test_accuracy)

        torch.cuda.empty_cache()
    return train_losses, train_accuracy_list, test_losses, test_accuracy_list


def train_loop(
        dataloader: DataLoader,
        model: nn.Module,
        loss_fn: nn.Module,
        optimizer: optim.Optimizer,
        verbose: int = None,
        device: str = CPU,
) -> t.Tuple[float, float]:
    model.train()

    size = len(dataloader.dataset)  # noqa
    num_batches = len(dataloader)
    avg_loss, avg_accuracy = 0, 0

    for batch, (x, y) in enumerate(dataloader):
        x, y = x.to(device), y.to(device)

        pred = model(x)
        loss = loss_fn(pred, y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        y_true = torch.flatten(y).detach().cpu()
        y_pred = torch.flatten(pred.argmax(1)).detach().cpu()
        accuracy = metrics.accuracy_score(y_true, y_pred)

        avg_loss += loss
        avg_accuracy += accuracy
        if verbose and batch % verbose == 0:
            print(f"[{batch * len(x):>4d}/{size:>4d}]: loss: {loss:.6f}, accuracy: {accuracy:.4f}")

        del x, y, pred, loss
        torch.cuda.empty_cache()

    return (avg_loss / num_batches).item(), avg_accuracy / num_batches


@torch.no_grad()
def test_loop(
        dataloader: DataLoader,
        model: nn.Module,
        loss_fn: nn.Module,
        device: str = CPU,
) -> t.Tuple[float, float]:
    model.eval()
    y_true, y_pred = get_y_true_y_pred(model, dataloader, device)
    return loss_fn(y_pred, y_true).item(), metrics.accuracy_score(y_true.cpu(), y_pred.argmax(1).cpu())


@torch.no_grad()
def get_y_true_y_pred(
        model: nn.Module,
        dataloader: DataLoader,
        device: str = CPU,
) -> t.Tuple[torch.Tensor, torch.Tensor]:
    model.eval()

    y_test = []
    y_pred = []
    for x, y in dataloader:
        x, y = x.to(device), y.to(device)
        pred = model(x)
        y_test.append(y.unsqueeze(1))
        y_pred.append(pred)

        del x
        torch.cuda.empty_cache()

    return torch.flatten(torch.vstack(y_test)), torch.vstack(y_pred)


def plot_train_test(
        train_losses: t.List[float],
        train_accuracy: t.List[float],
        test_losses: t.List[float],
        test_accuracy: t.List[float],
) -> None:
    fig, axes = plt.subplots(2, 1, figsize=(6, 7))
    epochs = torch.arange(len(train_losses))

    axes[0].plot(epochs, train_losses)
    axes[0].plot(epochs, test_losses)
    axes[0].set_ylabel("loss")
    axes[0].legend(["train", "test"])

    axes[1].plot(epochs, train_accuracy)
    axes[1].plot(epochs, test_accuracy)
    axes[1].set_xlabel("epoch")
    axes[1].set_ylabel("accuracy")

# %%
class SignClassifier(nn.Module):
    LAST_CONV_OUT_CHANNELS = 64
    ADAPTIVE_AVG_POOL = 4

    def __init__(self, num_channels: int, num_classes: int):
        super().__init__()
        self.features = nn.Sequential(
            nn.Conv2d(in_channels=num_channels, out_channels=32, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(True),
            nn.MaxPool2d(2),
            nn.Conv2d(in_channels=32, out_channels=32, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(True),
            nn.MaxPool2d(2),
            nn.Conv2d(in_channels=32, out_channels=self.LAST_CONV_OUT_CHANNELS, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(self.LAST_CONV_OUT_CHANNELS),
            nn.ReLU(True),
            nn.MaxPool2d(2),
        )
        self.avgpool = nn.AdaptiveAvgPool2d((self.ADAPTIVE_AVG_POOL, self.ADAPTIVE_AVG_POOL))
        self.classifier = nn.Linear(
            self.LAST_CONV_OUT_CHANNELS * self.ADAPTIVE_AVG_POOL * self.ADAPTIVE_AVG_POOL,
            num_classes,
        )

    def forward(self, x):
        x = self.features(x)
        x = self.avgpool(x)
        x = torch.flatten(x, 1)
        return self.classifier(x)

# %%
torch.manual_seed(0)

net = SignClassifier(
    num_channels=train_dataset[0][0].size(0),
    num_classes=len(sign_dataset.classes),
).to(DEVICE)
weights = get_weights(torch.tensor([target for _, target in train_dataset], device=DEVICE))
loss_fn = nn.CrossEntropyLoss(weight=weights)
optimizer = optim.Adam(net.parameters(), lr=0.001)

train_dataloader = DataLoader(train_dataset, batch_size=16, shuffle=True, num_workers=2)
test_dataloader = DataLoader(test_dataset, batch_size=256, num_workers=2)

net
# Out:
# SignClassifier(
#   (features): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU(inplace=True)
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU(inplace=True)
#     (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(4, 4))
#   (classifier): Linear(in_features=1024, out_features=10, bias=True)
# )

# %%
# %%time

if __name__ == '__main__':
    train_losses, train_accuracy, test_losses, test_accuracy = common_train(
        epochs=50,
        model=net,
        loss_fn=loss_fn,
        optimizer=optimizer,
        train_dataloader=train_dataloader,
        test_dataloader=test_dataloader,
        device=DEVICE,
    )
# Out:
# Epoch 1
# --------------------------------
# Train Error: loss: 2.231806, accuracy: 0.2049
#  Test Error: loss: 1.623803, accuracy: 0.4636
#
# Epoch 2
# --------------------------------
# Train Error: loss: 1.614998, accuracy: 0.4555
#  Test Error: loss: 1.716736, accuracy: 0.4102
#
# Epoch 3
# --------------------------------
# Train Error: loss: 1.230566, accuracy: 0.5757
#  Test Error: loss: 1.857969, accuracy: 0.3277
#
# Epoch 4
# --------------------------------
# Train Error: loss: 1.049919, accuracy: 0.6412
#  Test Error: loss: 0.680905, accuracy: 0.7694
#
# Epoch 5
# --------------------------------
# Train Error: loss: 0.939245, accuracy: 0.6833
#  Test Error: loss: 0.670769, accuracy: 0.7670
#
# Epoch 6
# --------------------------------
# Train Error: loss: 0.875432, accuracy: 0.6839
#  Test Error: loss: 2.463189, accuracy: 0.3107
#
# Epoch 7
# --------------------------------
# Train Error: loss: 0.756086, accuracy: 0.7434
#  Test Error: loss: 0.401682, accuracy: 0.8981
#
# Epoch 8
# --------------------------------
# Train Error: loss: 0.714416, accuracy: 0.7632
#  Test Error: loss: 0.522876, accuracy: 0.8228
#
# Epoch 9
# --------------------------------
# Train Error: loss: 0.654604, accuracy: 0.7770
#  Test Error: loss: 0.324342, accuracy: 0.9272
#
# Epoch 10
# --------------------------------
# Train Error: loss: 0.604076, accuracy: 0.7879
#  Test Error: loss: 0.456658, accuracy: 0.8641
#
# Epoch 11
# --------------------------------
# Train Error: loss: 0.616496, accuracy: 0.7969
#  Test Error: loss: 0.336670, accuracy: 0.9102
#
# Epoch 12
# --------------------------------
# Train Error: loss: 0.544161, accuracy: 0.8239
#  Test Error: loss: 0.477634, accuracy: 0.8301
#
# Epoch 13
# --------------------------------
# Train Error: loss: 0.512163, accuracy: 0.8239
#  Test Error: loss: 0.427284, accuracy: 0.8762
#
# Epoch 14
# --------------------------------
# Train Error: loss: 0.513104, accuracy: 0.8239
#  Test Error: loss: 0.670693, accuracy: 0.7718
#
# Epoch 15
# --------------------------------
# Train Error: loss: 0.494503, accuracy: 0.8359
#  Test Error: loss: 0.356377, accuracy: 0.8786
#
# Epoch 16
# --------------------------------
# Train Error: loss: 0.455428, accuracy: 0.8504
#  Test Error: loss: 0.400941, accuracy: 0.8544
#
# Epoch 17
# --------------------------------
# Train Error: loss: 0.458998, accuracy: 0.8383
#  Test Error: loss: 0.241094, accuracy: 0.9417
#
# Epoch 18
# --------------------------------
# Train Error: loss: 0.422208, accuracy: 0.8516
#  Test Error: loss: 0.299027, accuracy: 0.9029
#
# Epoch 19
# --------------------------------
# Train Error: loss: 0.403142, accuracy: 0.8690
#  Test Error: loss: 0.258836, accuracy: 0.9345
#
# Epoch 20
# --------------------------------
# Train Error: loss: 0.462075, accuracy: 0.8528
#  Test Error: loss: 0.272475, accuracy: 0.9320
#
# Epoch 21
# --------------------------------
# Train Error: loss: 0.399543, accuracy: 0.8642
#  Test Error: loss: 0.265157, accuracy: 0.9320
#
# Epoch 22
# --------------------------------
# Train Error: loss: 0.393187, accuracy: 0.8642
#  Test Error: loss: 0.336369, accuracy: 0.9053
#
# Epoch 23
# --------------------------------
# Train Error: loss: 0.413988, accuracy: 0.8552
#  Test Error: loss: 0.357341, accuracy: 0.8956
#
# Epoch 24
# --------------------------------
# Train Error: loss: 0.325620, accuracy: 0.8906
#  Test Error: loss: 0.362254, accuracy: 0.8714
#
# Epoch 25
# --------------------------------
# Train Error: loss: 0.367784, accuracy: 0.8822
#  Test Error: loss: 0.224464, accuracy: 0.9345
#
# Epoch 26
# --------------------------------
# Train Error: loss: 0.387631, accuracy: 0.8648
#  Test Error: loss: 0.336770, accuracy: 0.8956
#
# Epoch 27
# --------------------------------
# Train Error: loss: 0.339099, accuracy: 0.8900
#  Test Error: loss: 0.193241, accuracy: 0.9612
#
# Epoch 28
# --------------------------------
# Train Error: loss: 0.300303, accuracy: 0.9044
#  Test Error: loss: 0.218472, accuracy: 0.9393
#
# Epoch 29
# --------------------------------
# Train Error: loss: 0.316390, accuracy: 0.8990
#  Test Error: loss: 0.328588, accuracy: 0.8835
#
# Epoch 30
# --------------------------------
# Train Error: loss: 0.311712, accuracy: 0.8930
#  Test Error: loss: 0.202706, accuracy: 0.9490
#
# Epoch 31
# --------------------------------
# Train Error: loss: 0.309276, accuracy: 0.8942
#  Test Error: loss: 0.305948, accuracy: 0.9029
#
# Epoch 32
# --------------------------------
# Train Error: loss: 0.313172, accuracy: 0.8900
#  Test Error: loss: 0.194066, accuracy: 0.9636
#
# Epoch 33
# --------------------------------
# Train Error: loss: 0.293998, accuracy: 0.9008
#  Test Error: loss: 0.221042, accuracy: 0.9442
#
# Epoch 34
# --------------------------------
# Train Error: loss: 0.277828, accuracy: 0.9087
#  Test Error: loss: 0.379875, accuracy: 0.8617
#
# Epoch 35
# --------------------------------
# Train Error: loss: 0.246363, accuracy: 0.9153
#  Test Error: loss: 0.342749, accuracy: 0.8786
#
# Epoch 36
# --------------------------------
# Train Error: loss: 0.279783, accuracy: 0.9056
#  Test Error: loss: 0.296170, accuracy: 0.9175
#
# Epoch 37
# --------------------------------
# Train Error: loss: 0.328221, accuracy: 0.8924
#  Test Error: loss: 0.200707, accuracy: 0.9515
#
# Epoch 38
# --------------------------------
# Train Error: loss: 0.247853, accuracy: 0.9183
#  Test Error: loss: 0.394841, accuracy: 0.8641
#
# Epoch 39
# --------------------------------
# Train Error: loss: 0.251752, accuracy: 0.9159
#  Test Error: loss: 0.150254, accuracy: 0.9587
#
# Epoch 40
# --------------------------------
# Train Error: loss: 0.236537, accuracy: 0.9219
#  Test Error: loss: 0.281650, accuracy: 0.9126
#
# Epoch 41
# --------------------------------
# Train Error: loss: 0.266499, accuracy: 0.9038
#  Test Error: loss: 0.307519, accuracy: 0.8883
#
# Epoch 42
# --------------------------------
# Train Error: loss: 0.252623, accuracy: 0.9087
#  Test Error: loss: 0.153677, accuracy: 0.9709
#
# Epoch 43
# --------------------------------
# Train Error: loss: 0.264352, accuracy: 0.9044
#  Test Error: loss: 0.212428, accuracy: 0.9417
#
# Epoch 44
# --------------------------------
# Train Error: loss: 0.231808, accuracy: 0.9243
#  Test Error: loss: 0.188031, accuracy: 0.9515
#
# Epoch 45
# --------------------------------
# Train Error: loss: 0.269090, accuracy: 0.9099
#  Test Error: loss: 0.191204, accuracy: 0.9490
#
# Epoch 46
# --------------------------------
# Train Error: loss: 0.225730, accuracy: 0.9225
#  Test Error: loss: 0.144858, accuracy: 0.9612
#
# Epoch 47
# --------------------------------
# Train Error: loss: 0.246534, accuracy: 0.9153
#  Test Error: loss: 0.424469, accuracy: 0.8544
#
# Epoch 48
# --------------------------------
# Train Error: loss: 0.207074, accuracy: 0.9375
#  Test Error: loss: 0.157797, accuracy: 0.9587
#
# Epoch 49
# --------------------------------
# Train Error: loss: 0.259573, accuracy: 0.9099
#  Test Error: loss: 0.187177, accuracy: 0.9515
#
# Epoch 50
# --------------------------------
# Train Error: loss: 0.225614, accuracy: 0.9309
#  Test Error: loss: 0.147781, accuracy: 0.9709
#
# CPU times: total: 56.8 s
# Wall time: 6min

# %% [markdown]
# ## Оценка и выводы

# %%
plot_train_test(train_losses, train_accuracy, test_losses, test_accuracy)  # noqa

# %%
y_true, y_pred = get_y_true_y_pred(net, test_dataloader, DEVICE)
y_true, y_pred = y_true.cpu(), y_pred.argmax(1).cpu()

# %%
cm_display = metrics.ConfusionMatrixDisplay.from_predictions(
    y_true,
    y_pred,
    display_labels=sign_dataset.classes,
    colorbar=False,
    xticks_rotation=0,
    cmap=sns.color_palette('light:b', as_cmap=True)
)
cm_display.ax_.grid(False)
cm_display.figure_.set_size_inches(8, 8)

# %%
print(metrics.classification_report(y_true, y_pred, target_names=sign_dataset.classes, zero_division=True))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98        42
#            1       1.00      0.98      0.99        42
#            2       0.95      1.00      0.97        38
#            3       0.97      0.93      0.95        42
#            4       0.97      0.93      0.95        42
#            5       1.00      0.97      0.99        38
#            6       0.94      0.98      0.96        45
#            7       0.97      1.00      0.99        39
#            8       0.98      0.98      0.98        49
#            9       0.94      0.97      0.96        35
#
#     accuracy                           0.97       412
#    macro avg       0.97      0.97      0.97       412
# weighted avg       0.97      0.97      0.97       412

# %%
net.eval()

_, axes = plt.subplots(3, 3, figsize=(6, 7))
for i, ax in zip(torch.randperm(len(test_dataset)), axes.flatten()):
    img, _ = sign_dataset[test_dataset.indices[i]]  # картинка до нормализации

    x, target = test_dataset[i]
    pred = net(x.unsqueeze(0).to(DEVICE))

    pred_proba = torch.max(torch.softmax(pred, 1))
    pred_label = pred.argmax(1).item()
    ax.set_title(
        f"pred: {sign_dataset.classes[pred_label]} ({pred_proba:.2f})"
        f"\ntrue: {sign_dataset.classes[target]}", loc="left"
    )
    ax.axis("off")
    if img.mode == "RGB":
        ax.imshow(img)
    else:
        ax.imshow(img, cmap="gray")
